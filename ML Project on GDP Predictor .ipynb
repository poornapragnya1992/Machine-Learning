# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/wrwr.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Year                                    42 non-null     int64
#  1   GDP per captia price (US Dollar Price)  42 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 800.0 bytes

# %%
df.head(-1)
# Out:
#     Year  GDP per captia price (US Dollar Price)
# 0   1980                                 271.031
# 1   1981                                 274.726
# 2   1982                                 277.965
# 3   1983                                 296.291
# 4   1984                                 281.099
# 5   1985                                 302.945
# 6   1986                                 315.161
# 7   1987                                 346.171
# 8   1988                                 357.799
# 9   1989                                 352.182
# 10  1990                                 374.002
# 11  1991                                 308.370
# 12  1992                                 322.512
# 13  1993                                 306.440
# 14  1994                                 352.172
# 15  1995                                 380.321
# 16  1996                                 406.968
# 17  1997                                 422.809
# 18  1998                                 420.573
# 19  1999                                 449.725
# 20  2000                                 451.114
# 21  2001                                 459.473
# 22  2002                                 479.063
# 23  2003                                 556.326
# 24  2004                                 638.787
# 25  2005                                 726.918
# 26  2006                                 814.353
# 27  2007                                1046.898
# 28  2008                                1019.511
# 29  2009                                1121.248
# 30  2010                                1384.174
# 31  2011                                1458.105
# 32  2012                                1443.879
# 33  2013                                1449.605
# 34  2014                                1573.881
# 35  2015                                1605.605
# 36  2016                                1732.051
# 37  2017                                1980.694
# 38  2018                                1996.952
# 39  2019                                2098.933
# 40  2020                                1929.677

# %%
x = df ['Year'].values.reshape (-1,1)
y = df ['GDP per captia price (US Dollar Price)'].values.reshape (-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit (x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score (y_test, y_pred)
# Out:
# 0.8116687936604196

# %%
output = reg.predict([[2022]])
output
# Out:
# array([[1840.75810602]])
