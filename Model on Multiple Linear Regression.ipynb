# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv ('/content/drive/MyDrive/Advertising_data.csv')

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   2210
# 1   44.5   39.3       45.1   1040
# 2   17.2   45.9       69.3    930
# 3  151.5   41.3       58.5   1850
# 4  180.8   10.8       58.4   1290

# %%
data.describe()
# Out:
#                TV       radio   newspaper        sales
# count  200.000000  200.000000  200.000000   200.000000
# mean   147.042500   23.264000   30.554000  1402.250000
# std     85.854236   14.846809   21.778621   521.745657
# min      0.700000    0.000000    0.300000   160.000000
# 25%     74.375000    9.975000   12.750000  1037.500000
# 50%    149.750000   22.900000   25.750000  1290.000000
# 75%    218.825000   36.525000   45.100000  1740.000000
# max    296.400000   49.600000  114.000000  2700.000000

# %%
x = data.drop (['sales'],axis =1)
y = data ['sales'].values.reshape (-1,1)
print (x)
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x,y,test_size=0.3, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
multiple_reg = LinearRegression()
multiple_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = multiple_reg.predict (x_test)

# %%
from sklearn.metrics import r2_score
r2_score (y_test, y_pred)
# Out:
# 0.8609466508230368

# %%
output = multiple_reg.predict ([[85.6, 56.9, 85.8]])
output
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[1841.03965167]])

# %%
output = multiple_reg.predict([[9563,5865,789556]])
output
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[702695.0469012]])

# %%
sns.regplot (x = 'radio', y = 'sales',data=data)

# %%
print ("enter the amount you will invest on:")
tv = float (input ("TV:"))
radio = float (input ('Radio:'))
newspaper = float (input('Newspaper:'))

output = multiple_reg.predict ([[tv, radio, newspaper]])
print ("you will get Rs {:.2f} sales by advertising Rs{} on TV, Rs{} on Radio and Rs{} on Newspaper."\
       .format (output [0][0] if output else "not predictable", tv, radio, newspaper))
# Out:
# enter the amount you will invest on:
# TV:9563
# Radio:5865
# Newspaper:789556
# you will get Rs 702695.05 sales by advertising Rs9563.0 on TV, Rs5865.0 on Radio and Rs789556.0 on Newspaper.
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
