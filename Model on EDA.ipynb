# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %% [markdown]
# #Reading the Data

# %%
path = '/content/automobile.csv'

# %%
df =  pd.read_csv ('/content/automobile.csv')

# %%
df.head ()
# Out:
#    symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0          3                122  alfa-romero  ...            Medium      0   1
# 1          3                122  alfa-romero  ...            Medium      0   1
# 2          1                122  alfa-romero  ...            Medium      0   1
# 3          2                164         audi  ...            Medium      0   1
# 4          2                164         audi  ...            Medium      0   1
#
# [5 rows x 29 columns]

# %% [markdown]
# # Display the first 10 rows of the csv file

# %%
df.describe()
# Out:
#         symboling  normalized-losses  ...      diesel         gas
# count  201.000000          201.00000  ...  201.000000  201.000000
# mean     0.840796          122.00000  ...    0.099502    0.900498
# std      1.254802           31.99625  ...    0.300083    0.300083
# min     -2.000000           65.00000  ...    0.000000    0.000000
# 25%      0.000000          101.00000  ...    0.000000    1.000000
# 50%      1.000000          122.00000  ...    0.000000    1.000000
# 75%      2.000000          137.00000  ...    0.000000    1.000000
# max      3.000000          256.00000  ...    1.000000    1.000000
#
# [8 rows x 19 columns]

# %%
sns.boxplot (x='length', y='price', data=df)

# %%
sns.boxplot (x='engine-size', y = 'price', data=df)

# %%
sns.boxplot (x='num-of-cylinders', y='price', data=df)

# %%
plt.scatter(df['engine-size'],df['price'])
plt.xlabel('engine-size')
plt.ylabel('price')
plt.show()

# %%
count,bin_edges = np.histogram(df['peak-rpm'])
df['peak-rpm'].plot (kind = 'hist', xticks = bin_edges)
plt.xlabel ('value of peak rpm')
plt.ylabel ('number of cars')
plt.grid()
plt.show()

# %%
count,bin_edges = np.histogram(df['engine-size'])
df['engine-size'].plot (kind = 'hist', xticks = bin_edges)
plt.xlabel ('engine-size')
plt.ylabel ('number of cars')
plt.grid()
plt.show()

# %%
print(count)
# Out:
# [ 6 93 45 30 14  6  2  2  0  3]

# %%
print(bin_edges)
# Out:
# [ 61.   87.5 114.  140.5 167.  193.5 220.  246.5 273.  299.5 326. ]

# %%
sns.heatmap(df.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sns.regplot (x= 'engine-size', y= 'price', data=df)

# %%
correlation_matrix = df.corr()
sns.heatmap (correlation_matrix, annot= True)
sns.heatmap (correlation_matrix)
plt.show()

# %%
sns.regplot (x= 'engine-size', y='price', data=df)

# %%
sns.regplot(x='peak-rpm', y='city-mpg', data=df)

# %%
sr1=pd.series([90,65,56,85,12,85,95,15,0,74,65])
sr1.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-344af54e71c8> in <module>()
# ----> 1 sr1=pd.series([90,65,56,85,12,85,95,15,0,74,65])
#       2 sr1.describe()
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
sr1=pd.series([90,10,5,30,25,20,85,65,11,28])

# %%
sr1.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-6c868972709d> in <module>()
# ----> 1 sr1.describe()
#
# NameError: name 'sr1' is not defined

# %%
sr1 = pd.Series([90,10,5,30,80,25,20,20,85,65,11,28])

# %%
sr1.describe()
# Out:
# count    12.000000
# mean     39.083333
# std      31.586701
# min       5.000000
# 25%      17.750000
# 50%      26.500000
# 75%      68.750000
# max      90.000000
# dtype: float64

# %%
sr2 = pd.Series([98,00,25,65,-58,62,-78,65,37,85])

# %%
sr2.describe()
# Out:
# count    10.000000
# mean     30.100000
# std      59.165399
# min     -78.000000
# 25%       6.250000
# 50%      49.500000
# 75%      65.000000
# max      98.000000
# dtype: float64
