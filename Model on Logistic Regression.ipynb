# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv ('/content/drive/MyDrive/Sales.csv')

# %%
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
data.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
x = data.drop (['Purchased'], axis=1)
y = data ['Purchased'].values.reshape (-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x,y,test_size=0.3,random_state=28)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler ()
x_train = sc.fit_transform (x_train)
x_test = sc.transform (x_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit (x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix (y_test, y_pred)
print (cm)
accuracy_score (y_test, y_pred)
# Out:
# [[74  8]
#  [13 25]]
# 0.825

# %%
output = classifier.predict ([[30,8700]])
output
# Out:
# array([1])

# %%
print ("age and estimated salary:")
age = (input ("Age:"))
Estimatedsalary =  (input ("Estimatedsalary:")

output = classifier.predict ([[age, Estimatedsalary]])
print ("you will purchase if your age is {} and Estimatedsalary is {}."\
       .format (output [0][0] if output else "not predictable", age, Estimatedsalary))
# Out:
#   File "<ipython-input-36-832c289068df>", line 5
#     output = classifier.predict ([[age, Estimatedsalary]])
#          ^
# SyntaxError: invalid syntax
